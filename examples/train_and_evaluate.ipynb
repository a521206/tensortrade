# %% [markdown]
# # Train and Evaluate Tutorial
#
# This notebook covers feature engineering, reward schemes, and training a DQN agent on trading data.
#
# ## 📚 Related Tutorials
#
# Before diving in, review these essential tutorials:
#
# | Tutorial | Description |
# |----------|-------------|
# | [First Training](../docs/tutorials/04-training/01-first-training.md) | Getting started with training |
# | [Reward Schemes](../docs/tutorials/03-components/02-reward-schemes.md) | Why PBR works and reward design |
# | [Common Failures](../docs/tutorials/02-domains/track-b-rl-for-traders/02-common-failures.md) | **Critical pitfalls to avoid** |
# | [Overfitting](../docs/tutorials/05-advanced/01-overfitting.md) | Detection and prevention |
# | [Commission Analysis](../docs/tutorials/05-advanced/02-commission.md) | Key finding: commission destroys profits |
#
# ### ⚠️ Important Warning
#
# Our experiments show that agents **can predict market direction** (+$239 profit at 0% commission), but **overtrading destroys profits** when commission is applied (-$650 at 0.1% commission). See the [Commission Analysis](../docs/tutorials/05-advanced/02-commission.md) tutorial for details.
#
# ---

# %% [markdown]
# ## Install TensorTrade

# %%
#!python3 -m pip install git+https://github.com/tensortrade-org/tensortrade.git

# %% [markdown]
# ## Define global variables

# %%
n_steps = 1000
n_episodes = 20
window_size = 30
memory_capacity = n_steps * 10
save_path = 'agents/'
n_bins = 5             # Number of bins to partition the dataset evenly in order to evaluate class sparsity.
seed = 1337

# %% [markdown]
# ## Setup Data Fetching

# %%
from tensortrade.data.cdd import CryptoDataDownload

import warnings
import numpy as np
import pandas as pd

# Suppress deprecated pandas warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="pandas")
pd.set_option('future.no_silent_downcasting', True)

def prepare_data(df):
    df['volume'] = np.int64(df['volume'])
    df['date'] = pd.to_datetime(df['date'])
    df.sort_values(by='date', ascending=True, inplace=True)
    df.reset_index(drop=True, inplace=True)
    df['date'] = df['date'].dt.strftime('%Y-%m-%d %I:%M %p')
    return df

def fetch_data():
    cdd = CryptoDataDownload()
    bitfinex_data = cdd.fetch("Bitfinex", "USD", "BTC", "1h")
    bitfinex_data = bitfinex_data[['date', 'open', 'high', 'low', 'close', 'volume']]
    bitfinex_data = prepare_data(bitfinex_data)
    return bitfinex_data

def load_csv(filename):
    df = pd.read_csv('data/' + filename, skiprows=1)
    df.drop(columns=['symbol', 'volume_btc'], inplace=True)

    # Fix timestamp from "2019-10-17 09-AM" to "2019-10-17 09-00-00 AM"
    df['date'] = df['date'].str[:14] + '00-00 ' + df['date'].str[-2:]

    return prepare_data(df)

# %%
data = fetch_data()
data
# Out:
#                       date     open     high           low         close  \
# 0      1901-12-14 12:23 AM  57595.0  57938.0  57549.000000  57815.000000
# 1      1901-12-15 12:29 AM  43279.0  43308.0  43080.000000  43080.000000
# 2      1901-12-15 10:51 PM  38589.0  38875.0  38455.983293  38710.000000
# 3      1901-12-16 10:58 PM  43106.0  43152.0  43015.000000  43096.000000
# 4      1901-12-17 09:20 PM  23541.0  23581.0  23355.000000  23466.000000
# ...                    ...      ...      ...           ...           ...
# 65042  2038-01-14 11:33 AM  58112.0  58192.0  56993.000000  57118.000000
# 65043  2038-01-15 09:55 AM  34737.0  34975.0  34699.862680  34817.986857
# 65044  2038-01-16 10:01 AM  65870.0  66061.0  65743.000000  66010.000000
# 65045  2038-01-17 08:23 AM  43264.0  43840.0  42855.000000  43037.000000
# 65046  2038-01-18 08:29 AM  70132.0  71611.0  69625.000000  69856.000000
#
#          volume
# 0       5122459
# 1        966937
# 2       3511787
# 3        170464
# 4       4499322
# ...         ...
# 65042   4373701
# 65043   4870213
# 65044   3267628
# 65045  27669069
# 65046  50011595
#
# [65047 rows x 6 columns]

# %%
# pandas_ta is not used - the 'ta' library provides all needed indicators
# No additional installation needed

# %% [markdown]
# ## Create features for the feed module

# %%
import os
import numpy as np
import ta

def fix_dataset_inconsistencies(dataframe, fill_value=None):
    dataframe = dataframe.replace([-np.inf, np.inf], np.nan)

    # This is done to avoid filling middle holes with backfilling.
    if fill_value is None:
        dataframe.iloc[0,:] = \
            dataframe.apply(lambda column: column.iloc[column.first_valid_index()], axis='index')
    else:
        dataframe.iloc[0,:] = \
            dataframe.iloc[0,:].fillna(fill_value)

    float32_max = np.finfo(np.float32).max
    numeric_cols = dataframe.select_dtypes(include=[np.number]).columns
    dataframe[numeric_cols] = dataframe[numeric_cols].clip(
        lower=-float32_max,
        upper=float32_max
    )

    return dataframe.ffill().dropna(axis='columns')

def rsi(price: 'pd.Series[pd.Float64Dtype]', period: float) -> 'pd.Series[pd.Float64Dtype]':
    r = price.diff()
    upside = r.clip(lower=0)
    downside = -r.clip(upper=0)
    rs = upside.ewm(alpha=1 / period).mean() / downside.ewm(alpha=1 / period).mean()
    return 100*(1 - (1 + rs) ** -1)

def macd(price: 'pd.Series[pd.Float64Dtype]', fast: float, slow: float, signal: float) -> 'pd.Series[pd.Float64Dtype]':
    fm = price.ewm(span=fast, adjust=False).mean()
    sm = price.ewm(span=slow, adjust=False).mean()
    md = fm - sm
    signal = md - md.ewm(span=signal, adjust=False).mean()
    return signal

def generate_features(data):
    df = data.copy()

    # Generate all default indicators from ta library
    ta.add_all_ta_features(df, 
                            'open', 
                            'high', 
                            'low', 
                            'close', 
                            'volume', 
                            fillna=True)

    # Naming convention across most technical indicator libraries
    df = df.rename(columns={'open': 'Open', 
                                'high': 'High', 
                                'low': 'Low', 
                                'close': 'Close', 
                                'volume': 'Volume'})
    df = df.set_index('date')

    # Custom indicators
    features = pd.DataFrame.from_dict({
        'prev_open': df['Open'].shift(1),
        'prev_high': df['High'].shift(1),
        'prev_low': df['Low'].shift(1),
        'prev_close': df['Close'].shift(1),
        'prev_volume': df['Volume'].shift(1),
        'vol_5': df['Close'].rolling(window=5).std().abs(),
        'vol_10': df['Close'].rolling(window=10).std().abs(),
        'vol_20': df['Close'].rolling(window=20).std().abs(),
        'vol_30': df['Close'].rolling(window=30).std().abs(),
        'vol_50': df['Close'].rolling(window=50).std().abs(),
        'vol_60': df['Close'].rolling(window=60).std().abs(),
        'vol_100': df['Close'].rolling(window=100).std().abs(),
        'vol_200': df['Close'].rolling(window=200).std().abs(),
        'ma_5': df['Close'].rolling(window=5).mean(),
        'ma_10': df['Close'].rolling(window=10).mean(),
        'ma_20': df['Close'].rolling(window=20).mean(),
        'ma_30': df['Close'].rolling(window=30).mean(),
        'ma_50': df['Close'].rolling(window=50).mean(),
        'ma_60': df['Close'].rolling(window=60).mean(),
        'ma_100': df['Close'].rolling(window=100).mean(),
        'ma_200': df['Close'].rolling(window=200).mean(),
        'ema_5': ta.trend.ema_indicator(df['Close'], window=5, fillna=True),
        'ema_10': ta.trend.ema_indicator(df['Close'], window=10, fillna=True),
        'ema_20': ta.trend.ema_indicator(df['Close'], window=20, fillna=True),
        'ema_60': ta.trend.ema_indicator(df['Close'], window=60, fillna=True),
        'ema_64': ta.trend.ema_indicator(df['Close'], window=64, fillna=True),
        'ema_120': ta.trend.ema_indicator(df['Close'], window=120, fillna=True),
        'lr_open': np.log(df['Open']).diff().fillna(0),
        'lr_high': np.log(df['High']).diff().fillna(0),
        'lr_low': np.log(df['Low']).diff().fillna(0),
        'lr_close': np.log(df['Close']).diff().fillna(0),
        'r_volume': df['Close'].diff().fillna(0),
        'rsi_5': rsi(df['Close'], period=5),
        'rsi_10': rsi(df['Close'], period=10),
        'rsi_100': rsi(df['Close'], period=100),
        'rsi_7': rsi(df['Close'], period=7),
        'rsi_28': rsi(df['Close'], period=28),
        'rsi_6': rsi(df['Close'], period=6),
        'rsi_14': rsi(df['Close'], period=14),
        'rsi_26': rsi(df['Close'], period=24),
        'macd_normal': macd(df['Close'], fast=12, slow=26, signal=9),
        'macd_short': macd(df['Close'], fast=10, slow=50, signal=5),
        'macd_long': macd(df['Close'], fast=200, slow=100, signal=50),
    })

    # Concatenate custom features with ta-generated features
    data = pd.concat([df, features], axis='columns').ffill()

    # Remove potential column duplicates
    data = data.loc[:,~data.columns.duplicated()]

    # Revert naming convention
    data = data.rename(columns={'Open': 'open', 
                                'High': 'high', 
                                'Low': 'low', 
                                'Close': 'close', 
                                'Volume': 'volume'})

    data = data.reset_index()

    # A lot of indicators generate NaNs at the beginning of DataFrames, so remove them
    data = data.iloc[200:]
    data = data.reset_index(drop=True)

    data = fix_dataset_inconsistencies(data, fill_value=None)
    return data

# %%
data = generate_features(data)
data
# Out:
# c:\Users\agraw\GIT\tensortrade\.venv\Lib\site-packages\ta\volume.py:335: RuntimeWarning: overflow encountered in scalar multiply
#   self._nvi.iloc[i] = self._nvi.iloc[i - 1] * (1.0 + price_change.iloc[i])
#                       date          open     high          low         close  \
# 0      1903-03-21 05:20 AM  23467.671329  23561.0  23407.00000  23427.000000
# 1      1903-03-22 05:26 AM  34439.000000  34590.0  34385.00000  34533.000000
# 2      1903-03-24 03:54 AM  25751.000000  25787.0  25737.00000  25787.000000
# 3      1903-03-26 02:22 AM  29933.000000  29957.0  29926.00000  29926.000000
# 4      1903-03-28 12:51 AM  27170.000000  27192.0  27133.00000  27157.000000
# ...                    ...           ...      ...          ...           ...
# 64642  2038-01-14 11:33 AM  58112.000000  58192.0  56993.00000  57118.000000
# 64643  2038-01-15 09:55 AM  34737.000000  34975.0  34699.86268  34817.986857
# 64644  2038-01-16 10:01 AM  65870.000000  66061.0  65743.00000  66010.000000
# 64645  2038-01-17 08:23 AM  43264.000000  43840.0  42855.00000  43037.000000
# 64646  2038-01-18 08:29 AM  70132.000000  71611.0  69625.00000  69856.000000
#
#          volume    volume_adi    volume_obv  volume_cmf     volume_fi  ...  \
# 0       3320985  9.315904e+07    -533525293   -0.266115 -2.221147e+11  ...
# 1       1083523  9.364002e+07    -532441770   -0.255429 -1.886649e+11  ...
# 2         89953  9.372997e+07    -532531723   -0.256953 -1.618252e+11  ...
# 3         50164  9.367981e+07    -532481559   -0.334024 -1.386776e+11  ...
# 4        371954  9.361046e+07    -532853513   -0.283985 -1.190137e+11  ...
# ...         ...           ...           ...         ...           ...  ...
# 64642   4373701  1.137301e+10 -146860613660   -0.001327  2.467423e+09  ...
# 64643   4870213  1.137232e+10 -146865483873   -0.007023 -1.340018e+10  ...
# 64644   3267628  1.137454e+10 -146862216245    0.029562  3.074686e+09  ...
# 64645  27669069  1.135710e+10 -146889885314   -0.089494 -8.817049e+10  ...
# 64646  50011595  1.131872e+10 -146839873719   -0.297060  1.160340e+11  ...
#
#           rsi_10    rsi_100      rsi_7     rsi_28      rsi_6     rsi_14  \
# 0      43.490279  49.561403  39.034529  48.278555  36.271197  45.918250
# 1      46.390186  49.733812  44.572881  48.958818  43.715849  47.614707
# 2      44.396666  49.598951  41.139265  48.438531  39.369708  46.380843
# 3      45.625334  49.664198  43.540586  48.706052  42.609888  47.079749
# 4      44.888026  49.620790  42.196955  48.531358  40.856998  46.641737
# ...          ...        ...        ...        ...        ...        ...
# 64642  49.719246  50.066320  49.247357  50.119669  48.978935  49.967935
# 64643  46.370754  49.746466  43.828135  49.008909  42.131486  47.703918
# 64644  51.452229  50.196011  52.379460  50.597080  53.129998  51.045152
# 64645  47.749763  49.864167  46.320366  49.421407  45.488948  48.583183
# 64646  52.210454  50.251987  53.626508  50.805288  54.629859  51.522701
#
#           rsi_26  macd_normal   macd_short   macd_long
# 0      47.934391 -3417.676759 -4031.478401  -40.457250
# 1      48.754599 -3296.431767 -3578.473879  127.585295
# 2      48.131528 -3591.692835 -3880.449589  366.896893
# 3      48.456812 -3302.056967 -3320.938594  550.371868
# 4      48.245595 -3094.328587 -3001.345828  746.920707
# ...          ...          ...          ...         ...
# 64642  50.110540 -1522.773662 -1900.430090 -811.305855
# 64643  48.816252 -2956.940822 -3773.420721 -595.490849
# 64644  50.675702 -1738.575440 -1525.534729 -688.693858
# 64645  49.299283 -2374.244811 -2434.758770 -557.197691
# 64646  50.923097  -955.643907  -189.931320 -687.668321
#
# [64647 rows x 135 columns]

# %% [markdown]
# ## Remove features with low variance before splitting the dataset

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
date = data[['date']].copy()
data = data.drop(columns=['date'])
sel.fit(data)
data[data.columns[sel.get_support(indices=True)]]
data = pd.concat([date, data], axis='columns')
data
# Out:
#                       date          open     high          low         close  \
# 0      1903-03-21 05:20 AM  23467.671329  23561.0  23407.00000  23427.000000
# 1      1903-03-22 05:26 AM  34439.000000  34590.0  34385.00000  34533.000000
# 2      1903-03-24 03:54 AM  25751.000000  25787.0  25737.00000  25787.000000
# 3      1903-03-26 02:22 AM  29933.000000  29957.0  29926.00000  29926.000000
# 4      1903-03-28 12:51 AM  27170.000000  27192.0  27133.00000  27157.000000
# ...                    ...           ...      ...          ...           ...
# 64642  2038-01-14 11:33 AM  58112.000000  58192.0  56993.00000  57118.000000
# 64643  2038-01-15 09:55 AM  34737.000000  34975.0  34699.86268  34817.986857
# 64644  2038-01-16 10:01 AM  65870.000000  66061.0  65743.00000  66010.000000
# 64645  2038-01-17 08:23 AM  43264.000000  43840.0  42855.00000  43037.000000
# 64646  2038-01-18 08:29 AM  70132.000000  71611.0  69625.00000  69856.000000
#
#          volume    volume_adi    volume_obv  volume_cmf     volume_fi  ...  \
# 0       3320985  9.315904e+07    -533525293   -0.266115 -2.221147e+11  ...
# 1       1083523  9.364002e+07    -532441770   -0.255429 -1.886649e+11  ...
# 2         89953  9.372997e+07    -532531723   -0.256953 -1.618252e+11  ...
# 3         50164  9.367981e+07    -532481559   -0.334024 -1.386776e+11  ...
# 4        371954  9.361046e+07    -532853513   -0.283985 -1.190137e+11  ...
# ...         ...           ...           ...         ...           ...  ...
# 64642   4373701  1.137301e+10 -146860613660   -0.001327  2.467423e+09  ...
# 64643   4870213  1.137232e+10 -146865483873   -0.007023 -1.340018e+10  ...
# 64644   3267628  1.137454e+10 -146862216245    0.029562  3.074686e+09  ...
# 64645  27669069  1.135710e+10 -146889885314   -0.089494 -8.817049e+10  ...
# 64646  50011595  1.131872e+10 -146839873719   -0.297060  1.160340e+11  ...
#
#           rsi_10    rsi_100      rsi_7     rsi_28      rsi_6     rsi_14  \
# 0      43.490279  49.561403  39.034529  48.278555  36.271197  45.918250
# 1      46.390186  49.733812  44.572881  48.958818  43.715849  47.614707
# 2      44.396666  49.598951  41.139265  48.438531  39.369708  46.380843
# 3      45.625334  49.664198  43.540586  48.706052  42.609888  47.079749
# 4      44.888026  49.620790  42.196955  48.531358  40.856998  46.641737
# ...          ...        ...        ...        ...        ...        ...
# 64642  49.719246  50.066320  49.247357  50.119669  48.978935  49.967935
# 64643  46.370754  49.746466  43.828135  49.008909  42.131486  47.703918
# 64644  51.452229  50.196011  52.379460  50.597080  53.129998  51.045152
# 64645  47.749763  49.864167  46.320366  49.421407  45.488948  48.583183
# 64646  52.210454  50.251987  53.626508  50.805288  54.629859  51.522701
#
#           rsi_26  macd_normal   macd_short   macd_long
# 0      47.934391 -3417.676759 -4031.478401  -40.457250
# 1      48.754599 -3296.431767 -3578.473879  127.585295
# 2      48.131528 -3591.692835 -3880.449589  366.896893
# 3      48.456812 -3302.056967 -3320.938594  550.371868
# 4      48.245595 -3094.328587 -3001.345828  746.920707
# ...          ...          ...          ...         ...
# 64642  50.110540 -1522.773662 -1900.430090 -811.305855
# 64643  48.816252 -2956.940822 -3773.420721 -595.490849
# 64644  50.675702 -1738.575440 -1525.534729 -688.693858
# 64645  49.299283 -2374.244811 -2434.758770 -557.197691
# 64646  50.923097  -955.643907  -189.931320 -687.668321
#
# [64647 rows x 135 columns]

# %% [markdown]
# ## Split dataset

# %%
from sklearn.model_selection import train_test_split

def split_data(data):
    X = data.copy()
    y = X['close'].pct_change()

    X_train_test, X_valid, y_train_test, y_valid = \
        train_test_split(data, data['close'].pct_change(), train_size=0.67, test_size=0.33, shuffle=False)

    X_train, X_test, y_train, y_test = \
        train_test_split(X_train_test, y_train_test, train_size=0.50, test_size=0.50, shuffle=False)

    return X_train, X_test, X_valid, y_train, y_test, y_valid

# %%
X_train, X_test, X_valid, y_train, y_test, y_valid = \
    split_data(data)

import os
cwd = os.getcwd()
train_csv = os.path.join(cwd, 'train.csv')
test_csv = os.path.join(cwd, 'test.csv')
valid_csv = os.path.join(cwd, 'valid.csv')
X_train.to_csv(train_csv, index=False)
X_test.to_csv(test_csv, index=False)
X_valid.to_csv(valid_csv, index=False)

# %% [markdown]
# ## Get dataset statistics

# %%
from scipy.stats import iqr

def estimate_outliers(data):
    return iqr(data) * 1.5

def estimate_percent_gains(data, column='close'):
    returns = get_returns(data, column=column)
    gains = estimate_outliers(returns)
    return gains

def get_returns(data, column='close'):
    return fix_dataset_inconsistencies(data[[column]].pct_change(), fill_value=0)

def precalculate_ground_truths(data, column='close', threshold=None):
    returns = get_returns(data, column=column)
    gains = estimate_outliers(returns) if threshold is None else threshold
    binary_gains = (returns[column] > gains).astype(int)
    return binary_gains

def is_null(data):
    return data.isnull().sum().sum() > 0

def is_sparse(data, column='close'):
    binary_gains = precalculate_ground_truths(data, column=column)
    bins = [n * (binary_gains.shape[0] // n_bins) for n in range(n_bins)]
    bins += [binary_gains.shape[0]]
    bins = [binary_gains.iloc[bins[n]:bins[n + 1]] for n in range(n_bins)]
    return all([bin.astype(bool).any() for bin in bins])

def is_data_predictible(data, column):
    return not is_null(data) & is_sparse(data, column)

data.describe(include='all')
# Out:
#                        date           open           high            low  \
# count                 64647   64647.000000   64647.000000   64647.000000
# unique                64647            NaN            NaN            NaN
# top     1903-03-21 05:20 AM            NaN            NaN            NaN
# freq                      1            NaN            NaN            NaN
# mean                    NaN   36861.608305   37001.387643   36716.206364
# std                     NaN   31300.813342   31392.451064   31206.743619
# min                     NaN    3229.800000    3247.100000    3215.200000
# 25%                     NaN    9575.200000    9611.900000    9530.300000
# 50%                     NaN   27889.000000   27964.000000   27798.000000
# 75%                     NaN   56324.000000   56610.500000   55949.500000
# max                     NaN  125990.000000  126110.000000  125210.000000
#
#                 close        volume    volume_adi    volume_obv    volume_cmf  \
# count    64647.000000  6.464700e+04  6.464700e+04  6.464700e+04  64647.000000
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     36863.265932  5.592561e+06  7.255260e+09 -9.348420e+10      0.025705
# std      31301.946785  1.166672e+07  2.870439e+09  4.163749e+10      0.225705
# min       3229.800000  0.000000e+00 -7.024286e+07 -1.468899e+11     -0.851429
# 25%       9575.300000  8.008835e+05  5.089156e+09 -1.273505e+11     -0.123097
# 50%      27889.000000  2.186721e+06  8.423744e+09 -1.133366e+11      0.026538
# 75%      56328.500000  5.685232e+06  9.332196e+09 -5.820052e+10      0.175557
# max     126000.000000  4.868595e+08  1.153776e+10 -4.900852e+08      0.892317
#
#            volume_fi  ...        rsi_10       rsi_100         rsi_7  \
# count   6.464700e+04  ...  64647.000000  64647.000000  64647.000000
# unique           NaN  ...           NaN           NaN           NaN
# top              NaN  ...           NaN           NaN           NaN
# freq             NaN  ...           NaN           NaN           NaN
# mean   -5.667426e+10  ...     49.159811     49.993480     48.391135
# std     1.139786e+11  ...      6.551504      1.018995      8.612340
# min    -2.563240e+12  ...     22.195114     48.429607      8.498152
# 25%    -8.890711e+10  ...     46.731029     49.680348     45.034576
# 50%    -2.919155e+10  ...     47.480446     49.782069     46.303736
# 75%    -1.155884e+06  ...     50.030479     50.077385     49.911547
# max     1.677214e+12  ...     99.514483     85.437073     99.884096
#
#               rsi_28         rsi_6        rsi_14        rsi_26   macd_normal  \
# count   64647.000000  64647.000000  64647.000000  64647.000000  64647.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       49.902331     47.937313     49.573433     49.864389      0.105675
# std         2.976971      9.675720      5.105123      3.379270   2461.271315
# min        41.763112      5.526676     31.666140     40.155187  -4942.033461
# 25%        48.916851     44.254650     47.642444     48.725138  -1686.992601
# 50%        49.153995     45.643520     48.243326     49.003077   -150.961382
# 75%        50.158794     49.859333     50.115573     50.160139   1170.018536
# max        97.256021     99.955918     99.002029     97.729812   8417.595826
#
#           macd_short     macd_long
# count   64647.000000  64647.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        0.096871     -0.022150
# std      2851.272059    641.477555
# min     -5548.718664  -4418.238326
# 25%     -1902.335539   -541.905104
# 50%      -157.284081     -9.918311
# 75%       414.630666    228.854784
# max     11974.988715   4210.947579
#
# [11 rows x 135 columns]

# %% [markdown]
# ## Evaluate outlier sparsity of the data

# %%
import matplotlib.pyplot as plt
plt.plot(get_returns(data, column='close'))
plt.show()
is_data_predictible(data, 'close')
# Out:
# True

# %% [markdown]
# ## Percentage of the dataset generating rewards (keep between 5% to 15% or just rely on is_data_predictible())

# %%
plt.plot(precalculate_ground_truths(data, column='close').iloc[:1000])
plt.show()
percent_rewardable = str(round(100 + precalculate_ground_truths(data, column='close').value_counts().pct_change().iloc[-1] * 100, 2)) + '%'
print(percent_rewardable)
# Out:
# 22.21%

# %% [markdown]
# ## Threshold to pass to AnomalousProfit reward scheme

# %%
X_train_test = pd.concat([X_train, X_test], axis='index')
#threshold = estimate_percent_gains(X_train_test, 'close')
threshold = estimate_percent_gains(X_train, 'close')
threshold
# Out:
# 1.4652183415934172

# %% [markdown]
# ## Implement basic feature engineering

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

from feature_engine.selection import SelectBySingleFeaturePerformance

# %%
rf = RandomForestClassifier(n_estimators=10, 
                            random_state=seed, 
                            n_jobs=6)

sel = SelectBySingleFeaturePerformance(variables=None, 
                                       estimator=rf, 
                                       scoring="roc_auc", 
                                       cv=5, 
                                       threshold=0.5)

sel.fit(X_train, precalculate_ground_truths(X_train, column='close'))
# Out:
# SelectBySingleFeaturePerformance(cv=5,
#                                  estimator=RandomForestClassifier(n_estimators=10,
#                                                                   n_jobs=6,
#                                                                   random_state=1337),
#                                  threshold=0.5)

# %%
feature_performance = pd.Series(sel.feature_performance_).sort_values(ascending=False)
feature_performance
# Out:
# lr_close                   1.000000
# others_dlr                 1.000000
# others_dr                  1.000000
# lr_low                     0.998913
# lr_high                    0.998885
#                              ...
# volume_adi                 0.428333
# volume_vpt                 0.426664
# volume_obv                 0.413895
# trend_ichimoku_b           0.370012
# trend_visual_ichimoku_b    0.354953
# Length: 134, dtype: float64

# %%
feature_performance.plot.bar(figsize=(20, 5))
plt.title('Performance of ML models trained with individual features')
plt.ylabel('roc-auc')
# Out:
# Text(0, 0.5, 'roc-auc')

# %%
features_to_drop = sel.features_to_drop_
features_to_drop
# Out:
# ['volume_adi',
#  'volume_obv',
#  'volume_vpt',
#  'volatility_dcm',
#  'trend_ichimoku_base',
#  'trend_ichimoku_b',
#  'trend_visual_ichimoku_b',
#  'trend_psar_up',
#  'vol_100']

# %%
to_drop = list(set(features_to_drop) - set(['open', 'high', 'low', 'close', 'volume']))
len(to_drop)
# Out:
# 9

# %%
X_train = X_train.drop(columns=to_drop)
X_test = X_test.drop(columns=to_drop)
X_valid = X_valid.drop(columns=to_drop)

X_train.shape, X_test.shape, X_valid.shape
# Out:
# ((21723, 86), (21724, 86), (21400, 86))

# %%
X_train.columns.tolist()
# Out:
# ['date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'volume_adi',
#  'volume_obv',
#  'volume_cmf',
#  'volume_fi',
#  'volume_em',
#  'volume_sma_em',
#  'volume_vpt',
#  'volume_vwap',
#  'volume_mfi',
#  'volume_nvi',
#  'volatility_bbm',
#  'volatility_bbh',
#  'volatility_bbl',
#  'volatility_bbw',
#  'volatility_bbp',
#  'volatility_bbhi',
#  'volatility_bbli',
#  'volatility_kcc',
#  'volatility_kch',
#  'volatility_kcl',
#  'volatility_kcw',
#  'volatility_kcp',
#  'volatility_kchi',
#  'volatility_kcli',
#  'volatility_dcl',
#  'volatility_dch',
#  'volatility_dcm',
#  'volatility_dcw',
#  'volatility_dcp',
#  'volatility_atr',
#  'volatility_ui',
#  'trend_macd',
#  'trend_macd_signal',
#  'trend_macd_diff',
#  'trend_sma_fast',
#  'trend_sma_slow',
#  'trend_ema_fast',
#  'trend_ema_slow',
#  'trend_vortex_ind_pos',
#  'trend_vortex_ind_neg',
#  'trend_vortex_ind_diff',
#  'trend_trix',
#  'trend_mass_index',
#  'trend_dpo',
#  'trend_kst',
#  'trend_kst_sig',
#  'trend_kst_diff',
#  'trend_ichimoku_conv',
#  'trend_ichimoku_base',
#  'trend_ichimoku_a',
#  'trend_ichimoku_b',
#  'trend_stc',
#  'trend_adx',
#  'trend_adx_pos',
#  'trend_adx_neg',
#  'trend_cci',
#  'trend_visual_ichimoku_a',
#  'trend_visual_ichimoku_b',
#  'trend_aroon_up',
#  'trend_aroon_down',
#  'trend_aroon_ind',
#  'trend_psar_up',
#  'trend_psar_down',
#  'trend_psar_up_indicator',
#  'trend_psar_down_indicator',
#  'momentum_rsi',
#  'momentum_stoch_rsi',
#  'momentum_stoch_rsi_k',
#  'momentum_stoch_rsi_d',
#  'momentum_tsi',
#  'momentum_uo',
#  'momentum_stoch',
#  'momentum_stoch_signal',
#  'momentum_wr',
#  'momentum_ao',
#  'momentum_roc',
#  'momentum_ppo',
#  'momentum_ppo_signal',
#  'momentum_ppo_hist',
#  'momentum_pvo',
#  'momentum_pvo_signal',
#  'momentum_pvo_hist',
#  'momentum_kama',
#  'others_dr',
#  'others_dlr',
#  'others_cr',
#  'prev_open',
#  'prev_high',
#  'prev_low',
#  'prev_close',
#  'prev_volume',
#  'vol_5',
#  'vol_10',
#  'vol_20',
#  'vol_30',
#  'vol_50',
#  'vol_60',
#  'vol_100',
#  'vol_200',
#  'ma_5',
#  'ma_10',
#  'ma_20',
#  'ma_30',
#  'ma_50',
#  'ma_60',
#  'ma_100',
#  'ma_200',
#  'ema_5',
#  'ema_10',
#  'ema_20',
#  'ema_60',
#  'ema_64',
#  'ema_120',
#  'lr_open',
#  'lr_high',
#  'lr_low',
#  'lr_close',
#  'r_volume',
#  'rsi_5',
#  'rsi_10',
#  'rsi_100',
#  'rsi_7',
#  'rsi_28',
#  'rsi_6',
#  'rsi_14',
#  'rsi_26',
#  'macd_normal',
#  'macd_short',
#  'macd_long']

# %% [markdown]
# ## Normalize the dataset subsets to make the model converge faster

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler

scaler_type = MinMaxScaler

def get_feature_scalers(X, scaler_type=scaler_type):
    scalers = []
    for name in list(X.columns[X.columns != 'date']):
        scalers.append(scaler_type().fit(X[name].values.reshape(-1, 1)))
    return scalers

def get_scaler_transforms(X, scalers):
    X_scaled = []
    for name, scaler in zip(list(X.columns[X.columns != 'date']), scalers):
        X_scaled.append(scaler.transform(X[name].values.reshape(-1, 1)))
    X_scaled = pd.concat([pd.DataFrame(column, columns=[name]) for name, column in \
                          zip(list(X.columns[X.columns != 'date']), X_scaled)], axis='columns')
    return X_scaled

def normalize_data(X_train, X_test, X_valid):
    X_train_test = pd.concat([X_train, X_test], axis='index')
    X_train_test_valid = pd.concat([X_train_test, X_valid], axis='index')

    X_train_test_dates = X_train_test[['date']]
    X_train_test_valid_dates = X_train_test_valid[['date']]

    X_train_test = X_train_test.drop(columns=['date'])
    X_train_test_valid = X_train_test_valid.drop(columns=['date'])

    train_test_scalers = \
        get_feature_scalers(X_train_test, 
                            scaler_type=scaler_type)
    train_test_valid_scalers = \
        get_feature_scalers(X_train_test_valid, 
                            scaler_type=scaler_type)

    X_train_test_scaled = \
        get_scaler_transforms(X_train_test, 
                              train_test_scalers)
    X_train_test_valid_scaled = \
        get_scaler_transforms(X_train_test_valid, 
                              train_test_scalers)
    X_train_test_valid_scaled_leaking = \
        get_scaler_transforms(X_train_test_valid, 
                              train_test_valid_scalers)

    X_train_test_scaled = \
        pd.concat([X_train_test_dates, 
                   X_train_test_scaled], 
                  axis='columns')
    X_train_test_valid_scaled = \
        pd.concat([X_train_test_valid_dates, 
                   X_train_test_valid_scaled], 
                  axis='columns')
    X_train_test_valid_scaled_leaking = \
        pd.concat([X_train_test_valid_dates, 
                   X_train_test_valid_scaled_leaking], 
                  axis='columns')

    X_train_scaled = X_train_test_scaled.iloc[:X_train.shape[0]]
    X_test_scaled = X_train_test_scaled.iloc[X_train.shape[0]:]
    X_valid_scaled = X_train_test_valid_scaled.iloc[X_train_test.shape[0]:]
    X_valid_scaled_leaking = X_train_test_valid_scaled_leaking.iloc[X_train_test.shape[0]:]

    return (train_test_scalers, 
            train_test_valid_scalers, 
            X_train_scaled, 
            X_test_scaled, 
            X_valid_scaled, 
            X_valid_scaled_leaking)

# %%
train_test_scalers, train_test_valid_scalers, X_train_scaled, X_test_scaled, X_valid_scaled, X_valid_scaled_leaking = \
    normalize_data(X_train, X_test, X_valid)

# %% [markdown]
# ## Write a reward scheme encouraging rare volatile upside trades

# %%
from tensortrade.env.default.rewards import TensorTradeRewardScheme


class AnomalousProfit(TensorTradeRewardScheme):
    """A simple reward scheme that rewards the agent for exceeding a 
    precalculated percentage in the net worth.

    Parameters
    ----------
    threshold : float
        The minimum value to exceed in order to get the reward.

    Attributes
    ----------
    threshold : float
        The minimum value to exceed in order to get the reward.
    """

    registered_name = "anomalous"

    def __init__(self, threshold: float = 0.02, window_size: int = 1):
        self._window_size = self.default('window_size', window_size)
        self._threshold = self.default('threshold', threshold)

    def get_reward(self, portfolio: 'Portfolio') -> float:
        """Rewards the agent for incremental increases in net worth over a
        sliding window.

        Parameters
        ----------
        portfolio : `Portfolio`
            The portfolio being used by the environment.

        Returns
        -------
        int
            Whether the last percent change in net worth exceeds the predefined 
            `threshold`.
        """
        performance = pd.DataFrame.from_dict(portfolio.performance).T
        current_step = performance.shape[0]
        if current_step > 1:
            # Hint: make it cumulative.
            net_worths = performance['net_worth']
            ground_truths = precalculate_ground_truths(performance, 
                                                       column='net_worth', 
                                                       threshold=self._threshold)
            reward_factor = 2.0 * ground_truths - 1.0
            #return net_worths.iloc[-1] / net_worths.iloc[-min(current_step, self._window_size + 1)] - 1.0
            return (reward_factor * net_worths.abs()).iloc[-1]

        else:
            return 0.0

# %%
class PenalizedProfit(TensorTradeRewardScheme):
    """A reward scheme which penalizes net worth loss and 
    decays with the time spent.

    Parameters
    ----------
    cash_penalty_proportion : float
        cash_penalty_proportion

    Attributes
    ----------
    cash_penalty_proportion : float
        cash_penalty_proportion.
    """

    registered_name = "penalized"

    def __init__(self, cash_penalty_proportion: float = 0.10):
        self._cash_penalty_proportion = \
            self.default('cash_penalty_proportion', 
                         cash_penalty_proportion)

    def get_reward(self, portfolio: 'Portfolio') -> float:
        """Rewards the agent for gaining net worth while holding the asset.

        Parameters
        ----------
        portfolio : `Portfolio`
            The portfolio being used by the environment.

        Returns
        -------
        int
            A penalized reward.
        """
        performance = pd.DataFrame.from_dict(portfolio.performance).T
        current_step = performance.shape[0]
        if current_step > 1:
            initial_amount = portfolio.initial_net_worth
            net_worth = performance['net_worth'].iloc[-1]
            cash_worth = performance['bitstamp:/USD:/total'].iloc[-1]
            cash_penalty = max(0, (net_worth * self._cash_penalty_proportion - cash_worth))
            net_worth -= cash_penalty
            reward = (net_worth / initial_amount) - 1
            reward /= current_step
            return reward
        else:
            return 0.0

# %% [markdown]
# ## TODO: implement tuning

# %% [markdown]
# ## Setup Trading Environment

# %%
import tensortrade.env.default as default

from tensortrade.agents import DQNAgent
from tensortrade.feed.core import DataFeed, Stream
from tensortrade.feed.core.base import NameSpace
from tensortrade.env.default.actions import BSH
from tensortrade.env.default.rewards import RiskAdjustedReturns, SimpleProfit
from tensortrade.oms.exchanges import Exchange, ExchangeOptions
from tensortrade.oms.services.execution.simulated import execute_order
from tensortrade.oms.instruments import USD, BTC, ETH
from tensortrade.oms.wallets import Wallet, Portfolio
from tensortrade.oms.orders import TradeType

# TODO: adjust according to your commission percentage, if present
commission = 0.001
price = Stream.source(list(X_train["close"]), 
                      dtype="float").rename("USD-BTC")
#bitstamp_options = ExchangeOptions(commission=commission)
#bitstamp = Exchange("bitstamp", 
#                    service=execute_order, 
#                    options=bitstamp_options)(price)
bitstamp = Exchange("bitstamp", 
                    service=execute_order)(price)

cash = Wallet(bitstamp, 50000 * USD)
asset = Wallet(bitstamp, 0 * BTC)

portfolio = Portfolio(USD, [cash, asset])

with NameSpace("bitstamp"):
    features = [
        Stream.source(list(X_train_scaled[c]), 
                      dtype="float").rename(c) for c in X_train_scaled.columns[1:]
        #Stream.source(list(X_train_scaled['lr_close']), dtype="float").rename('lr_close')
    ]

feed = DataFeed(features)
feed.compile()

renderer_feed = DataFeed([
    Stream.source(list(X_train["date"])).rename("date"),
    Stream.source(list(X_train["open"]), dtype="float").rename("open"),
    Stream.source(list(X_train["high"]), dtype="float").rename("high"),
    Stream.source(list(X_train["low"]), dtype="float").rename("low"),
    Stream.source(list(X_train["close"]), dtype="float").rename("close"), 
    Stream.source(list(X_train["volume"]), dtype="float").rename("volume") 
])

action_scheme = BSH(
    cash=cash,
    asset=asset
)

#reward_scheme = RiskAdjustedReturns(return_algorithm='sortino',
#                                    window_size=30)

#reward_scheme = SimpleProfit(window_size=30)

reward_scheme = AnomalousProfit(threshold=threshold)

#reward_scheme = PenalizedProfit(cash_penalty_proportion=0.1)

env = default.create(
    portfolio=portfolio,
    action_scheme=action_scheme,
    reward_scheme=reward_scheme,
    feed=feed,
    renderer_feed=renderer_feed,
    renderer=default.renderers.PlotlyTradingChart(),
    window_size=30
)

# %%
env.observer.feed.next()
# Out:
# {'internal': {'bitstamp:/USD-BTC': 23427.0,
#   'bitstamp:/USD:/free': 50000.0,
#   'bitstamp:/USD:/locked': 0.0,
#   'bitstamp:/USD:/total': 50000.0,
#   'bitstamp:/BTC:/free': 0.0,
#   'bitstamp:/BTC:/locked': 0.0,
#   'bitstamp:/BTC:/total': 0.0,
#   'bitstamp:/BTC:/worth': 0.0,
#   'net_worth': 50000.0},
#  'external': {'bitstamp:/open': 0.16485694328161735,
#   'bitstamp:/high': 0.16533794986118672,
#   'bitstamp:/low': 0.1655136120555958,
#   'bitstamp:/close': 0.16451223505378343,
#   'bitstamp:/volume': 0.006821239289912725,
#   'bitstamp:/volume_adi': 0.01753876209609903,
#   'bitstamp:/volume_obv': 0.9996600529049405,
#   'bitstamp:/volume_cmf': 0.3356644680990887,
#   'bitstamp:/volume_fi': 0.5520931075040297,
#   'bitstamp:/volume_em': 0.5666438610934111,
#   'bitstamp:/volume_sma_em': 0.5616117645229316,
#   'bitstamp:/volume_vpt': 0.026667972251287617,
#   'bitstamp:/volume_vwap': 0.4776272683201646,
#   'bitstamp:/volume_mfi': 0.22657609968279013,
#   'bitstamp:/volume_nvi': 4.5189582913020616e-29,
#   'bitstamp:/volatility_bbm': 0.8312895685304549,
#   'bitstamp:/volatility_bbh': 0.7122036053840769,
#   'bitstamp:/volatility_bbl': 0.8546631286579882,
#   'bitstamp:/volatility_bbw': 0.13382383489177563,
#   'bitstamp:/volatility_bbp': 0.294203653660622,
#   'bitstamp:/volatility_bbhi': 0.0,
#   'bitstamp:/volatility_bbli': 0.0,
#   'bitstamp:/volatility_kcc': 0.6210688878509234,
#   'bitstamp:/volatility_kch': 0.6265636860328003,
#   'bitstamp:/volatility_kcl': 0.6154310085906665,
#   'bitstamp:/volatility_kcw': 0.3067943459345698,
#   'bitstamp:/volatility_kcp': 0.10210018573744652,
#   'bitstamp:/volatility_kchi': 0.0,
#   'bitstamp:/volatility_kcli': 1.0,
#   'bitstamp:/volatility_dcl': 0.5921383703130223,
#   'bitstamp:/volatility_dch': 0.8654442619959862,
#   'bitstamp:/volatility_dcm': 0.910469356335598,
#   'bitstamp:/volatility_dcw': 0.12232519301125502,
#   'bitstamp:/volatility_dcp': 0.00023206432823178586,
#   'bitstamp:/volatility_atr': 0.39652392260976843,
#   'bitstamp:/volatility_ui': 0.5486002807671053,
#   'bitstamp:/trend_macd': 0.3560267903615374,
#   'bitstamp:/trend_macd_signal': 0.5895252345640088,
#   'bitstamp:/trend_macd_diff': 0.0739129074371172,
#   'bitstamp:/trend_sma_fast': 0.6420021843427323,
#   'bitstamp:/trend_sma_slow': 0.9113445201370236,
#   'bitstamp:/trend_ema_fast': 0.6785882091042408,
#   'bitstamp:/trend_ema_slow': 0.8503734034230083,
#   'bitstamp:/trend_vortex_ind_pos': 0.48213807379139695,
#   'bitstamp:/trend_vortex_ind_neg': 0.5235261655642292,
#   'bitstamp:/trend_vortex_ind_diff': 0.5045292464966014,
#   'bitstamp:/trend_trix': 0.303601584621432,
#   'bitstamp:/trend_mass_index': 0.7425394536061308,
#   'bitstamp:/trend_dpo': 0.3303379149367046,
#   'bitstamp:/trend_kst': 0.28902422268587596,
#   'bitstamp:/trend_kst_sig': 0.33776328275269957,
#   'bitstamp:/trend_kst_diff': 0.35635359689871887,
#   'bitstamp:/trend_ichimoku_conv': 0.5980328564208288,
#   'bitstamp:/trend_ichimoku_base': 0.9235295743050639,
#   'bitstamp:/trend_ichimoku_a': 0.7834973156400279,
#   'bitstamp:/trend_ichimoku_b': 0.9126152981245057,
#   'bitstamp:/trend_stc': 0.004616766254056442,
#   'bitstamp:/trend_adx': 0.11794031461738284,
#   'bitstamp:/trend_adx_pos': 0.22219150032895285,
#   'bitstamp:/trend_adx_neg': 0.9345818016365688,
#   'bitstamp:/trend_cci': 0.3012612456249614,
#   'bitstamp:/trend_visual_ichimoku_a': 0.8753425103013432,
#   'bitstamp:/trend_visual_ichimoku_b': 0.9153363665483452,
#   'bitstamp:/trend_aroon_up': 0.0,
#   'bitstamp:/trend_aroon_down': 0.12,
#   'bitstamp:/trend_aroon_ind': 0.44,
#   'bitstamp:/trend_psar_up': 0.6211776626251088,
#   'bitstamp:/trend_psar_down': 0.7738787980161469,
#   'bitstamp:/trend_psar_up_indicator': 0.0,
#   'bitstamp:/trend_psar_down_indicator': 0.0,
#   'bitstamp:/momentum_rsi': 0.0817777080528933,
#   'bitstamp:/momentum_stoch_rsi': 0.0,
#   'bitstamp:/momentum_stoch_rsi_k': 0.10540088195868913,
#   'bitstamp:/momentum_stoch_rsi_d': 0.16001637101994093,
#   'bitstamp:/momentum_tsi': 0.14055122279563617,
#   'bitstamp:/momentum_uo': 0.24031601153522758,
#   'bitstamp:/momentum_stoch': 0.00042959017097688796,
#   'bitstamp:/momentum_stoch_signal': 0.12393959140145015,
#   'bitstamp:/momentum_wr': 0.000429590170976879,
#   'bitstamp:/momentum_ao': 0.37567952027487783,
#   'bitstamp:/momentum_roc': 0.010853542858912494,
#   'bitstamp:/momentum_ppo': 0.2783519425380276,
#   'bitstamp:/momentum_ppo_signal': 0.5419168328514777,
#   'bitstamp:/momentum_ppo_hist': 0.12151296632231592,
#   'bitstamp:/momentum_pvo': 0.5158938526597147,
#   'bitstamp:/momentum_pvo_signal': 0.7375204038142803,
#   'bitstamp:/momentum_pvo_hist': 0.1529717987576376,
#   'bitstamp:/momentum_kama': 0.7683018141458958,
#   'bitstamp:/others_dr': 0.015153522009611987,
#   'bitstamp:/others_dlr': 0.41590165720748945,
#   'bitstamp:/others_cr': 0.16451223505378346,
#   'bitstamp:/prev_open': 0.32312752830314717,
#   'bitstamp:/prev_high': 0.32305846598118715,
#   'bitstamp:/prev_low': 0.3201513507133091,
#   'bitstamp:/prev_close': 0.31931364451634026,
#   'bitstamp:/prev_volume': 0.006624219401557999,
#   'bitstamp:/vol_5': 0.22110975609568928,
#   'bitstamp:/vol_10': 0.2947312430381422,
#   'bitstamp:/vol_20': 0.5168895849790015,
#   'bitstamp:/vol_30': 0.8685870653732067,
#   'bitstamp:/vol_50': 0.719687898221455,
#   'bitstamp:/vol_60': 0.790779464073321,
#   'bitstamp:/vol_100': 0.8825451943120994,
#   'bitstamp:/vol_200': 0.856411826011938,
#   'bitstamp:/ma_5': 0.5137297485107837,
#   'bitstamp:/ma_10': 0.6200804737391271,
#   'bitstamp:/ma_20': 0.8312895685304547,
#   'bitstamp:/ma_30': 0.9461908029124195,
#   'bitstamp:/ma_50': 0.8697132733753553,
#   'bitstamp:/ma_60': 0.9255534266245949,
#   'bitstamp:/ma_100': 0.9605134942549278,
#   'bitstamp:/ma_200': 0.9536212249919879,
#   'bitstamp:/ema_5': 0.47939807759864994,
#   'bitstamp:/ema_10': 0.6330635751076581,
#   'bitstamp:/ema_20': 0.802902942507116,
#   'bitstamp:/ema_60': 0.9292545945207455,
#   'bitstamp:/ema_64': 0.9320893719145826,
#   'bitstamp:/ema_120': 0.9513011616499408,
#   'bitstamp:/lr_open': 0.4150249640163045,
#   'bitstamp:/lr_high': 0.41525037466699427,
#   'bitstamp:/lr_low': 0.4173103224836338,
#   'bitstamp:/lr_close': 0.41590165720748945,
#   'bitstamp:/r_volume': 0.41698685911837796,
#   'bitstamp:/rsi_5': 0.26342447276411496,
#   'bitstamp:/rsi_10': 0.1697205279745766,
#   'bitstamp:/rsi_100': 0.009337339310483861,
#   'bitstamp:/rsi_7': 0.2524373454307197,
#   'bitstamp:/rsi_28': 0.026470328658518838,
#   'bitstamp:/rsi_6': 0.264633434947378,
#   'bitstamp:/rsi_14': 0.0817777422852054,
#   'bitstamp:/rsi_26': 0.03319771926180204,
#   'bitstamp:/macd_normal': 0.07391300318559535,
#   'bitstamp:/macd_short': 0.06447629199356986,
#   'bitstamp:/macd_long': 0.27052256658666324},
#  'renderer': {'date': '1903-03-21 05:20 AM',
#   'open': 23467.67132864,
#   'high': 23561.0,
#   'low': 23407.0,
#   'close': 23427.0,
#   'volume': 3320985}}

# %% [markdown]
# ## Setup and Train DQN Agent

# %%
def get_optimal_batch_size(window_size=30, n_steps=1000, batch_factor=4, stride=1):
    """
    lookback = 30          # Days of past data (also named window_size).
    batch_factor = 4       # batch_size = (sample_size - lookback - stride) // batch_factor
    stride = 1             # Time series shift into the future.
    """
    lookback = window_size
    sample_size = n_steps
    batch_size = ((sample_size - lookback - stride) // batch_factor)
    return batch_size

batch_size = get_optimal_batch_size(window_size=window_size, n_steps=n_steps, batch_factor=4)
batch_size
# Out:
# 242

# %%
agent = DQNAgent(env)

agent.train(batch_size=batch_size, 
            n_steps=n_steps, 
            n_episodes=n_episodes, 
            memory_capacity=memory_capacity, 
            save_path=save_path)
# Out:
# C:\Users\agraw\AppData\Local\Temp\ipykernel_26484\1908556242.py:1: DeprecationWarning: Call to deprecated class DQNAgent. (Builtin agents are being deprecated in favor of external implementations (ie: Ray)) -- Deprecated since version 1.0.4.
#   agent = DQNAgent(env)
# ====      AGENT ID: ab275e68-8a1d-43fd-880f-b8769840d4f7      ====
# FigureWidget({
#     'data': [{'name': 'Price',
#               'showlegend': False,
#               'type': 'candlestick',
#               'uid': '83bbf14a-02ee-4778-832b-db5e7bde5da1',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'marker': {'color': 'DodgerBlue'},
#               'name': 'Volume',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': 'c75b902d-fef3-4b6f-95d3-91a1d6675541',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD-BTC',
#               'type': 'scatter',
#               'uid': 'a342b1cb-e13a-4b6a-914c-78eb4aed44c8',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/free',
#               'type': 'scatter',
#               'uid': 'ca05ae33-6802-4fb4-bfe8-313e40830ee4',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/locked',
#               'type': 'scatter',
#               'uid': '1d5083ae-9fad-40b9-925c-5d3ce9fd1d9d',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/total',
#               'type': 'scatter',
#               'uid': 'ae485ce5-b506-44d7-833e-5625a0e514fc',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/free',
#               'type': 'scatter',
#               'uid': 'a5d1fd1c-d6a4-47f8-ba07-5c8562c34ecc',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/locked',
#               'type': 'scatter',
#               'uid': '5bb95d3a-a695-4d65-b1ac-f2ccd7a79959',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/total',
#               'type': 'scatter',
#               'uid': 'e6717731-5883-42c2-8a2e-effc86733d5f',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/worth',
#               'type': 'scatter',
#               'uid': 'c9cbfe93-4344-4691-804e-80268e769c19',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'net_worth',
#               'type': 'scatter',
#               'uid': '5a8e55ac-0352-43d5-b4fd-101b6165f792',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'marker': {'color': 'DarkGreen'},
#               'mode': 'lines',
#               'name': 'Net Worth',
#               'type': 'scatter',
#               'uid': '4b268912-54a9-4b0c-8509-33984001db66',
#               'xaxis': 'x4',
#               'yaxis': 'y4'}],
#     'layout': {'margin': {'t': 50},
#                'template': '...',
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'Gainsboro',
#                          'linecolor': 'Grey',
#                          'matches': 'x4',
#                          'rangeslider': {'visible': False},
#                          'showticklabels': False,
#                          'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Price'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'matches': 'x4',
#                           'showticklabels': False,
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Volume'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'matches': 'x4',
#                           'showticklabels': False,
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Performance'}},
#                'xaxis4': {'anchor': 'y4',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Net Worth'}},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.49950000000000006, 1.0],
#                          'gridcolor': 'Gainsboro',
#                          'linecolor': 'Grey'},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.333, 0.46950000000000003],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey'},
#                'yaxis3': {'anchor': 'x3',
#                           'domain': [0.1665, 0.30300000000000005],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey'},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.1365], 'gridcolor': 'Gainsboro', 'linecolor': 'Grey'}}
# })
# FigureWidget({
#     'data': [{'close': {'bdata': ('AAAAAMDg1kAAAAAAoNzgQAAAAADALt' ... 'dxfbPSQAAAAACAfPxAAAAAAMCO1kA='),
#                         'dtype': 'f8'},
#               'high': {'bdata': ('AAAAAEAC10AAAAAAwOPgQAAAAADALt' ... 'AAAL/SQAAAAACAi/xAAAAAAECk1kA='),
#                        'dtype': 'f8'},
#               'low': {'bdata': ('AAAAAMDb1kAAAAAAIMrgQAAAAABAIt' ... 'AAQJbSQAAAAACgcPxAAAAAAMCE1kA='),
#                       'dtype': 'f8'},
#               'name': 'Price',
#               'open': {'bdata': ('a2YM9+rq1kAAAAAA4NDgQAAAAADAJd' ... 'AAwKPSQAAAAACgcPxAAAAAAACF1kA='),
#                        'dtype': 'f8'},
#               'showlegend': False,
#               'type': 'candlestick',
#               'uid': '83bbf14a-02ee-4778-832b-db5e7bde5da1',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'marker': {'color': 'DodgerBlue'},
#               'name': 'Volume',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': 'c75b902d-fef3-4b6f-95d3-91a1d6675541',
#               'xaxis': 'x2',
#               'y': {'bdata': ('mawyAIOIEABhXwEA9MMAAPKsBQAHNg' ... 'APVAcA0LuFAI+YFAI0CQsAd5g8AA=='),
#                     'dtype': 'i4'},
#               'yaxis': 'y2'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD-BTC',
#               'type': 'scatter',
#               'uid': 'a342b1cb-e13a-4b6a-914c-78eb4aed44c8',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAMDg1kAAAAAAoNzgQAAAAADALt' ... 'dxfbPSQAAAAACAfPxAAAAAAMCO1kA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/free',
#               'type': 'scatter',
#               'uid': 'ca05ae33-6802-4fb4-bfe8-313e40830ee4',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAABq6EAAAAAAAAAAAClcj8Ld4v' ... 'AAEG0uQQAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/locked',
#               'type': 'scatter',
#               'uid': '1d5083ae-9fad-40b9-925c-5d3ce9fd1d9d',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/USD:/total',
#               'type': 'scatter',
#               'uid': 'ae485ce5-b506-44d7-833e-5625a0e514fc',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAABq6EAAAAAAAAAAAClcj8Ld4v' ... 'AAEG0uQQAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/free',
#               'type': 'scatter',
#               'uid': 'a5d1fd1c-d6a4-47f8-ba07-5c8562c34ecc',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAAAACykOts6QUBQAAAAAAAAA' ... 'taystiQNNushXNSGlA026yFc1IaUA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/locked',
#               'type': 'scatter',
#               'uid': '5bb95d3a-a695-4d65-b1ac-f2ccd7a79959',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/total',
#               'type': 'scatter',
#               'uid': 'e6717731-5883-42c2-8a2e-effc86733d5f',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAAAACykOts6QUBQAAAAAAAAA' ... 'taystiQNNushXNSGlA026yFc1IaUA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'bitstamp:/BTC:/worth',
#               'type': 'scatter',
#               'uid': 'c9cbfe93-4344-4691-804e-80268e769c19',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAAAADreKPxpPDxQAAAAAAAAA' ... 'rqHvhFQTCL5LASgnZBK3bJwdfSUUE='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'mode': 'lines',
#               'name': 'net_worth',
#               'type': 'scatter',
#               'uid': '5a8e55ac-0352-43d5-b4fd-101b6165f792',
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAABq6EDreKPxpPDxQClcj8Ld4v' ... 'rqYpNNQTCL5LASgnZBK3bJwdfSUUE='),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'marker': {'color': 'DarkGreen'},
#               'mode': 'lines',
#               'name': 'Net Worth',
#               'type': 'scatter',
#               'uid': '4b268912-54a9-4b0c-8509-33984001db66',
#               'xaxis': 'x4',
#               'y': {'bdata': ('AAAAAABq6EDreKPxpPDxQClcj8Ld4v' ... 'rqYpNNQTCL5LASgnZBK3bJwdfSUUE='),
#                     'dtype': 'f8'},
#               'yaxis': 'y4'}],
#     'layout': {'annotations': [{'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 299 [1904-03-05 01:12 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 298,
#                                 'xref': 'x',
#                                 'y': 19149.96,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 298 [1904-03-04 02:50 AM]' ... '.0 USD - Comm.: 0.02736727 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 297,
#                                 'xref': 'x',
#                                 'y': 109620.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 294 [1904-02-26 07:19 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 293,
#                                 'xref': 'x',
#                                 'y': 30443.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 293 [1904-02-24 08:51 AM]' ... '.0 USD - Comm.: 0.11074197 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 292,
#                                 'xref': 'x',
#                                 'y': 27090.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 290 [1904-02-18 01:26 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 289,
#                                 'xref': 'x',
#                                 'y': 34313.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 288 [1904-02-16 02:58 PM]' ... '.0 USD - Comm.: 0.07080314 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 287,
#                                 'xref': 'x',
#                                 'y': 42371.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 287 [1904-02-15 02:51 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 286,
#                                 'xref': 'x',
#                                 'y': 46850.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 285 [1904-02-13 04:23 PM]' ... '.0 USD - Comm.: 0.05105948 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 284,
#                                 'xref': 'x',
#                                 'y': 58755.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 284 [1904-02-12 06:01 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 283,
#                                 'xref': 'x',
#                                 'y': 70601.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 280 [1904-02-08 09:05 PM]' ... '.0 USD - Comm.: 0.05297545 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 279,
#                                 'xref': 'x',
#                                 'y': 56630.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 279 [1904-02-07 08:58 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 278,
#                                 'xref': 'x',
#                                 'y': 47042.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 278 [1904-02-06 10:36 PM]' ... '.0 USD - Comm.: 0.04686475 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 277,
#                                 'xref': 'x',
#                                 'y': 64014.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 277 [1904-02-05 10:30 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 276,
#                                 'xref': 'x',
#                                 'y': 59982.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 274 [1904-02-03 01:40 AM]' ... '.0 USD - Comm.: 0.03062850 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 273,
#                                 'xref': 'x',
#                                 'y': 97948.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 269 [1904-01-29 04:37 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 268,
#                                 'xref': 'x',
#                                 'y': 38816.08,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 268 [1904-01-28 06:15 AM]' ... '.0 USD - Comm.: 0.03169271 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 267,
#                                 'xref': 'x',
#                                 'y': 94659.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 267 [1904-01-27 06:09 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 266,
#                                 'xref': 'x',
#                                 'y': 20406.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 266 [1904-01-26 07:47 AM]' ... '.0 USD - Comm.: 0.02871363 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 265,
#                                 'xref': 'x',
#                                 'y': 104480.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 264 [1904-01-24 09:18 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 263,
#                                 'xref': 'x',
#                                 'y': 116480.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 263 [1904-01-23 09:12 AM]' ... '.0 USD - Comm.: 0.15717504 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 262,
#                                 'xref': 'x',
#                                 'y': 19087.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 262 [1904-01-22 10:50 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 261,
#                                 'xref': 'x',
#                                 'y': 109820.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 261 [1904-01-21 10:44 AM]' ... '.0 USD - Comm.: 0.18098456 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 260,
#                                 'xref': 'x',
#                                 'y': 16576.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 254 [1904-01-07 09:26 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 253,
#                                 'xref': 'x',
#                                 'y': 34275.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 253 [1904-01-06 09:20 PM]' ... '.0 USD - Comm.: 0.12560710 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 252,
#                                 'xref': 'x',
#                                 'y': 23884.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 252 [1904-01-05 10:58 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 251,
#                                 'xref': 'x',
#                                 'y': 42544.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 251 [1904-01-04 10:51 PM]' ... '.0 USD - Comm.: 0.06459392 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 250,
#                                 'xref': 'x',
#                                 'y': 46444.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 247 [1904-01-01 01:55 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 246,
#                                 'xref': 'x',
#                                 'y': 40410.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 244 [1903-12-29 05:05 AM]' ... '.0 USD - Comm.: 0.05305697 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 243,
#                                 'xref': 'x',
#                                 'y': 56543.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 243 [1903-12-28 04:58 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 242,
#                                 'xref': 'x',
#                                 'y': 46949.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 242 [1903-12-27 06:36 AM]' ... '.0 USD - Comm.: 0.04669988 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 241,
#                                 'xref': 'x',
#                                 'y': 64240.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 239 [1903-12-24 08:02 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 238,
#                                 'xref': 'x',
#                                 'y': 47519.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 238 [1903-12-23 09:40 AM]' ... '.0 USD - Comm.: 0.03083343 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 237,
#                                 'xref': 'x',
#                                 'y': 97297.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 237 [1903-12-22 09:33 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 236,
#                                 'xref': 'x',
#                                 'y': 34906.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 234 [1903-12-19 12:43 PM]' ... '.0 USD - Comm.: 0.03732411 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 233,
#                                 'xref': 'x',
#                                 'y': 80377.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 231 [1903-12-16 02:09 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 230,
#                                 'xref': 'x',
#                                 'y': 20650.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 228 [1903-12-13 05:18 PM]' ... '.0 USD - Comm.: 0.02603263 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 227,
#                                 'xref': 'x',
#                                 'y': 115240.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 225 [1903-12-10 06:44 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 224,
#                                 'xref': 'x',
#                                 'y': 16491.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 224 [1903-12-08 08:16 PM]' ... '.0 USD - Comm.: 0.17797817 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 223,
#                                 'xref': 'x',
#                                 'y': 16856.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 223 [1903-12-06 09:47 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 222,
#                                 'xref': 'x',
#                                 'y': 23812.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 221 [1903-12-03 12:51 AM]' ... '.0 USD - Comm.: 0.11105764 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 220,
#                                 'xref': 'x',
#                                 'y': 27013.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 217 [1903-11-26 05:20 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 216,
#                                 'xref': 'x',
#                                 'y': 23864.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 215 [1903-11-24 06:51 AM]' ... '.0 USD - Comm.: 0.06705628 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 214,
#                                 'xref': 'x',
#                                 'y': 44738.54,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 214 [1903-11-23 08:29 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 213,
#                                 'xref': 'x',
#                                 'y': 43163.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 213 [1903-11-22 08:23 AM]' ... '.0 USD - Comm.: 0.05123126 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 212,
#                                 'xref': 'x',
#                                 'y': 58558.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 211 [1903-11-20 09:55 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 210,
#                                 'xref': 'x',
#                                 'y': 40561.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 209 [1903-11-18 11:26 AM]' ... '.0 USD - Comm.: 0.09005826 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 208,
#                                 'xref': 'x',
#                                 'y': 33311.77,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 208 [1903-11-17 01:05 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 207,
#                                 'xref': 'x',
#                                 'y': 56503.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 207 [1903-11-16 12:58 PM]' ... '.0 USD - Comm.: 0.06380671 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 206,
#                                 'xref': 'x',
#                                 'y': 47017.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 203 [1903-11-12 04:02 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 202,
#                                 'xref': 'x',
#                                 'y': 50305.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 202 [1903-11-11 05:40 PM]' ... '.0 USD - Comm.: 0.03084357 BTC'),
# ...
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 433 [1904-08-02 05:20 AM]' ... '.0 USD - Comm.: 0.13274336 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 432,
#                                 'xref': 'x',
#                                 'y': 22600.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 432 [1904-08-01 06:58 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 431,
#                                 'xref': 'x',
#                                 'y': 42465.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 429 [1904-07-29 08:23 AM]' ... '.0 USD - Comm.: 0.05103780 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 428,
#                                 'xref': 'x',
#                                 'y': 58779.96,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 427 [1904-07-27 09:55 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 426,
#                                 'xref': 'x',
#                                 'y': 37597.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 426 [1904-07-26 11:33 AM]' ... '.0 USD - Comm.: 0.04559617 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 425,
#                                 'xref': 'x',
#                                 'y': 65795.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 425 [1904-07-25 11:26 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 424,
#                                 'xref': 'x',
#                                 'y': 32424.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 424 [1904-07-24 01:05 PM]' ... '.0 USD - Comm.: 0.05285878 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 423,
#                                 'xref': 'x',
#                                 'y': 56755.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 422 [1904-07-22 02:36 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 421,
#                                 'xref': 'x',
#                                 'y': 64087.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 421 [1904-07-21 02:30 PM]' ... '.0 USD - Comm.: 0.04857563 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 420,
#                                 'xref': 'x',
#                                 'y': 61759.36,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 420 [1904-07-20 04:08 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 419,
#                                 'xref': 'x',
#                                 'y': 62937.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 419 [1904-07-19 04:02 PM]' ... '.0 USD - Comm.: 0.06317385 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 418,
#                                 'xref': 'x',
#                                 'y': 47488.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 418 [1904-07-18 05:40 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 417,
#                                 'xref': 'x',
#                                 'y': 98088.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 416 [1904-07-16 07:12 PM]' ... '.0 USD - Comm.: 0.02887392 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 415,
#                                 'xref': 'x',
#                                 'y': 103900.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 415 [1904-07-15 07:05 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 414,
#                                 'xref': 'x',
#                                 'y': 38693.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 414 [1904-07-14 08:43 PM]' ... '.0 USD - Comm.: 0.03661752 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 413,
#                                 'xref': 'x',
#                                 'y': 81928.0,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 413 [1904-07-13 08:37 PM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 412,
#                                 'xref': 'x',
#                                 'y': 38951.08,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'FireBrick',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': -15,
#                                 'hoverlabel': {'bgcolor': 'FireBrick'},
#                                 'hovertext': ('Step 407 [1904-07-08 01:12 AM]' ... '.0 USD - Comm.: 0.15370041 BTC'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 406,
#                                 'xref': 'x',
#                                 'y': 19518.49,
#                                 'yref': 'y'},
#                                {'arrowcolor': 'DarkGreen',
#                                 'arrowhead': 2,
#                                 'arrowsize': 0.8,
#                                 'arrowwidth': 4,
#                                 'ax': 0,
#                                 'ay': 15,
#                                 'hoverlabel': {'bgcolor': 'DarkGreen'},
#                                 'hovertext': ('Step 402 [1904-06-30 07:19 AM]' ... '009.0 USD - Comm.: 2991.00 USD'),
#                                 'opacity': 0.6,
#                                 'showarrow': True,
#                                 'x': 401,
#                                 'xref': 'x',
#                                 'y': 30406.0,
#                                 'yref': 'y'}],
#                'margin': {'t': 50},
#                'template': '...',
#                'title': {'text': '[2026-07-15 12:28:00] Episode: 1/20 Step: 501/1000'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'Gainsboro',
#                          'linecolor': 'Grey',
#                          'matches': 'x4',
#                          'rangeslider': {'visible': False},
#                          'showticklabels': False,
#                          'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Price'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'matches': 'x4',
#                           'showticklabels': False,
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Volume'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'matches': 'x4',
#                           'showticklabels': False,
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Performance'}},
#                'xaxis4': {'anchor': 'y4',
#                           'domain': [0.0, 1.0],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey',
#                           'title': {'font': {'size': 12}, 'standoff': 7, 'text': 'Net Worth'}},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.49950000000000006, 1.0],
#                          'gridcolor': 'Gainsboro',
#                          'linecolor': 'Grey'},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.333, 0.46950000000000003],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey'},
#                'yaxis3': {'anchor': 'x3',
#                           'domain': [0.1665, 0.30300000000000005],
#                           'gridcolor': 'Gainsboro',
#                           'linecolor': 'Grey'},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.1365], 'gridcolor': 'Gainsboro', 'linecolor': 'Grey'}}
# })

# %% [markdown]
# ## Implement validation here

# %% [markdown]
# ## Print basic quantstats report
